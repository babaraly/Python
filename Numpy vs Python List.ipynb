# %%
l = range(1000000)

# %%
import numpy as np

# %%
a = np.arange(1000000)

# %%
# %time for i in range(1,10): r=[x*2 for x in l]
# Out:
# CPU times: user 692 ms, sys: 204 ms, total: 896 ms
# Wall time: 894 ms

# %%
# %time for i in range(1,10): r=a*2
# Out:
# CPU times: user 30.1 ms, sys: 4.47 ms, total: 34.5 ms
# Wall time: 32.4 ms
