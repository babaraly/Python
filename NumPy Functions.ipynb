# %%
import numpy as np

# %%
X = np.array([10,16,3,7,8,9])

# %%
X
# Out:
# array([10, 16,  3,  7,  8,  9])

# %%
np.sqrt(X)
# Out:
# array([3.16227766, 4.        , 1.73205081, 2.64575131, 2.82842712,
#        3.        ])

# %%
np.power(X,2)
# Out:
# array([100, 256,   9,  49,  64,  81])

# %%
y = np.array([12,6,8,9,13,17])

# %%
np.maximum(X,y)
# Out:
# array([12, 16,  8,  9, 13, 17])
