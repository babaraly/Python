# %%
import numpy as np

# %%
z = np.array([0,-1,40000,24000])

# %%
np.where(z<=0,26000,z)
# Out:
# array([26000, 26000, 40000, 24000])

# %%
np.where(z<=0,"Not Ok","ok")
# Out:
# array(['Not Ok', 'Not Ok', 'ok', 'ok'], dtype='<U6')
